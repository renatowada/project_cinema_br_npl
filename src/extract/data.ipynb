# %% [markdown]
# Montar essa lista de filmes vencedores é o diabo encarnado!!
#
# - O Fetival de Gramado tem um histórico com os vencedores de anos anteriores, mas o texto, ordem, premiações **NÃO** estão padronizados. Cada ano está de um jeito;
#
# - Mudei. Tô usando o letterboxd, pois o público é mais cinéfilo;
#
# - Para 1 filme, preciso acessar até 3 ou 4 sites diferentes.
#
# Minha intenção era incluir outros festivais de cinema na lista, mas, o trampo para **1** festival foi tão excruciante que vou analisar só o de Gramado mesmo. (foram 114 títulos)

# %%
import pandas as pd
import unidecode
import re

# %%
highlights = [
    # Longa-metragens vencedores do Festival de Gramado de 2015
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2014, "award_category": ["filme", "direção", "roteiro", "música"], "title": "Ausência", "directed by": " Chico Teixeira", "duration": 87, "rating": 3.26, "vote_count": 444, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2014, "award_category": ["ator", "júri da crítica"], "title": "O Último Cine Drive-in", "directed by": "Iberê Carvalho", "duration": 100, "rating": 3.34, "vote_count": 891, "type": "lm", "genre": ["Comédia", "Drama", "Família"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2015, "award_category": ["ator", "fotografia"], "title": "Um Homem Só", "directed by": "Cláudia Jouvin", "duration": 88, "rating": 3.26, "vote_count": 579, "type": "lm", "genre": ["Drama", "Ficção científica", "Romance"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2014, "award_category": ["júri popular"], "title": "O Outro Lado do Paraíso", "directed by": "André Ristum", "duration": 100, "rating": 3.37, "vote_count": 170, "type": "lm", "genre": ["Drama", "História"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2016, "award_category": ["montagem"], "title": "Ponto Zero", "directed by": "José Pedro Goulart", "duration": 84, "rating": 3.20, "vote_count": 560, "type": "lm", "genre": ["Drama"]},

    # Curta-metragens vencedores do Festival de Gramado de 2015
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2015, "award_category": ["filme", "fotografia"], "title": "O corpo", "directed by": "Lucas Cassales", "duration": 17, "rating": 3.25, "vote_count": 24, "type": "cm", "genre": ["Drama", "Fantasia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2015, "award_category": ["direção"], "title": "O Teto Sobre Nós", "directed by": "Bruno Carboni", "duration": 22, "rating": 3.44, "vote_count": 32, "type": "cm", "genre": ["Crime", "Mistério"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2015, "award_category": ["ator", "roteiro"], "title": "Quando Parei de Me Preocupar com Canalhas", "directed by": "Tiago Vieira", "duration": 15, "rating":3.49, "vote_count": 330, "type": "cm", "genre": ["Comédia", "Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2015, "award_category": ["júri popular"], "title": "Bá", "directed by": "Leandro Tadashi", "duration": 14, "rating": 3.77, "vote_count": 56, "type": "cm", "genre": ["Drama", "Família"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2015, "award_category": ["júri da crítica"], "title": "Dá Licença de Contar", "directed by": "Pedro Serrano", "duration": 17, "rating": 3.49, "vote_count": 245, "type": "cm", "genre": ["Comédia", "Drama", "Música"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2015, "release_year": 2015, "award_category": ["direção de arte", "música"], "title": "Miss & Grubs", "directed by": ["Camila Kamimura", "Jonas Brandão"], "duration": 10, "rating": 4.17, "vote_count": 3, "type": "cm", "genre": ["Animação"]},


    # Longa-metragens vencedores do Festival de Gramado de 2016
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["filem", "direção", "música"], "title": "Barata Ribeiro, 716", "directed by": "Domingos de Oliveira", "duration": 85, "rating": 3.42, "vote_count": 378, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["ator", "montagem", "júri popular"], "title": "Elis", "directed by": "Hugo Prata", "duration": 110, "rating": 3.32, "vote_count": 18744, "type": "lm", "genre": ["Biografia", "Drama", "Música"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["ator", "roteiro", "fotografia", "direção de arte"], "title": "O Roubo da Taça", "directed by": "Caito Ortiz", "duration": 90, "rating": 3.28, "vote_count": 948, "type": "lm", "genre": ["Comédia", "História"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["júri da crítica", "especial do júri"], "title": "O Silêncio do Céu", "directed by": "Marco Dutra", "duration": 102, "rating": 3.35, "vote_count": 2681, "type": "lm", "genre": ["Drama", "Suspense"]},

    # Curta-metragens vencedores do Festival de Gramado de 2016
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["filme", "roteiro", "especial do júri"], "title": "Rosinha", "directed by": "Gui Campos", "duration": 15, "rating": 3.68, "vote_count": 42, "type": "cm", "genre": ["Comédia", "Drama", "Família", "Romance"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["direção", "ator"], "title": "Aqueles Cinco Segundos", "directed by": "Felipe Saleme", "duration": 15, "rating": 2.86, "vote_count": 11, "type": "cm", "genre": ["Comédia", "Romance"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["ator"], "title": "O Que Teria Acontecido ou Não Naquela Calma e Misteriosa Tarde de Domingo no Jardim Zoológico", "directed by": ["Gugu Seppi", "Allan Souza Lima"], "duration": 15, "rating": 3.17, "vote_count": 18, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["fotografia"], "title": "Horas", "directed by": "Boca Migotto", "duration": 13, "rating": 3.30, "vote_count": 10, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2016, "release_year": 2016, "award_category": ["música", "júri popular", "especial do júri"], "title": "Super Oldboy", "directed by": ["Rafaella Costa", "Eliane Coster"], "duration": 15, "rating": 2.90, "vote_count": 30, "type": "cm", "genre": ["Comédia"]},


    # Longa-metragens vencedores do Festival de Gramado de 2017
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["filme", "diretor", "ator", "montagem"], "title": "Como Nossos Pais", "directed by": "Laís Bodanzky", "duration": 102, "rating": 3.44, "vote_count": 8678, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["roteiro", "direção de arte", "júri da crítica"], "title": "As Duas Irenes", "directed by": "Fabio Meira", "duration": 89, "rating": 3.45, "vote_count": 8598, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["fotografia", "música"], "title": "O Matador", "directed by": "Marcelo Galvão", "duration": 107, "rating": 2.8, "vote_count": 1769, "type": "lm", "genre": ["Faroeste"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["júri popular", "especial do júri"], "title": "Bio", "directed by": "Carlos Gerbase", "duration": 105, "rating": 2.65, "vote_count": 82, "type": "lm", "genre": ["Ficção científica"]},
    
    # Curta-metragens vencedores do Festival de Gramado de 2017
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2016, "award_category": ["filme", "montagem", "júri popular"], "title": "A Gis", "directed by": "Thiago Carvalhaes", "duration": 20, "rating": 4.14, "vote_count": 113, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["diretor"], "title": "Tailor", "directed by": "Tomas Cali", "duration": 10, "rating": 3.61, "vote_count": 83, "type": "cm", "genre": ["Animação", "Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["ator"], "title": "O Espirito do Bosque", "directed by": "Carla Saavedra Brychcy", "duration": 15, "rating": 3.38, "vote_count": 8, "type": "cm", "genre": ["Família", "Fantasia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["ator", "fotografia"], "title": "Telentrega", "directed by": "Roberto Burd", "duration": 10, "rating": 3.30, "vote_count": 15, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2016, "award_category": ["roteiro"], "title": "Postergados", "directed by": "Carolina Markowicz", "duration": 17, "rating": 3.36, "vote_count": 632, "type": "cm", "genre": ["Comédia", "Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["música", "direção de arte"], "title": "O Violeiro Fantasma", "directed by": "Wesley Rodrigues", "duration": 7, "rating": 3.42, "vote_count": 53, "type": "cm", "genre": ["Animação"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["júri da vrítica"], "title": "O Quebra-Cabeça de Sara", "directed by": "Allan Ribeiro", "duration": 10, "rating": 3.81, "vote_count": 74, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2017, "release_year": 2017, "award_category": ["especial do júri"], "title": "Cabelo Bom", "directed by": "Swahili Vidal", "duration": 15, "rating": 3.66, "vote_count": 29, "type": "cm", "genre": ["Drama", "Documentário"]},


    # Longa-metragens vencedores do Festival de Gramado de 2018
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2019, "award_category": ["música", "direção de arte", "fotografia"], "title": "Simonal", "directed by": "Leonardo Domingues", "duration": 105, "rating": 3.25, "vote_count": 2067, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2018, "award_category": ["montagem", "diretor"], "title": "A Voz do Silêncio", "directed by": "André Ristum", "duration": 98, "rating": 3.18, "vote_count": 342, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2018, "award_category": ["roteiro", "filme"], "title": "Ferrugem", "directed by": "Aly Muritiba", "duration": 100, "rating": 2.98, "vote_count": 1775, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2018, "award_category": ["ator"], "title": "10 Segundos para Vencer", "directed by": "José Alvarenga Jr.", "duration": 122, "rating": 3.27, "vote_count": 386, "type": "lm", "genre": ["Drama", "História"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2018, "award_category": ["ator", "júri popular", "júri da crítica"], "title": "Benzinho", "directed by": "Gustavo Pizzi", "duration": 95, "rating": 3.75, "vote_count": 8905, "type": "lm", "genre": ["Drama"]},

    # Curta-metragens vencedores do Festival de Gramado de 2018
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2017, "award_category": ["júri da crítica", "direção de arte", "júri popular"], "title": "Torre", "directed by": "Nádia Mangolini", "duration": 20, "rating": 3.77, "vote_count": 373, "type": "cm", "genre": ["Documentário", "Animação"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2017, "award_category": ["música", "roteiro", "ator"], "title": "A Retirada para um Coração Bruto", "directed by": "Marco Antônio Pereira", "duration": 15, "rating": 3.55, "vote_count": 233, "type": "cm", "genre": ["Ficção científia", "Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2018, "award_category": ["montagem"], "title": "Aquarela", "directed by": ["Thiago Kistenmacker", "Al Danuzio"], "duration": 15, "rating": 3.43, "vote_count": 23, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2017, "award_category": ["fotografia"], "title": "Nova Iorque", "directed by": "Leo Tabosa", "duration": 24, "rating": 3.71, "vote_count": 124, "type": "cm", "genre": ["Drama", "Fantasia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2018, "award_category": ["ator"], "title": "Catadora de Gente", "directed by": "Mirela Kruel", "duration": 18, "rating": 3.82, "vote_count": 73, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2016, "award_category": ["especial do júri"], "title": "Estamos Todos Aqui", "directed by": ["Rafael Mellim", "Chica Andrade"], "duration": 19, "rating": 3.72, "vote_count": 418, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2018, "award_category": ["diretor"], "title": "Kairo", "directed by": "Fabio Rodrigo", "duration": 15, "rating": 3.41, "vote_count": 100, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2018, "release_year": 2018, "award_category": ["filme"], "title": "Guaxuma", "directed by": "Nara Normande", "duration": 14, "rating": 4.10, "vote_count": 2808, "type": "cm", "genre": ["Drama", "Animação"]},
    

    # Longa-metragens vencedores do Festival de Gramado de 2019
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["filme", "diretor", "ator", "roteiro", "júri popular"], "title": "Pacarrete", "directed by": "", "duration": 97, "rating": 3.71, "vote_count": 7373, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["ator", "música"], "title": "O Homem Cordial", "directed by": "", "duration": 83, "rating": 3.10, "vote_count": 743, "type": "lm", "genre": ["Drama", "Suspense"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["fotografia"], "title": "Raia 4", "directed by": "", "duration": 97, "rating": 3.34, "vote_count": 292, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["montagem"], "title": "Hebe: A Estrela do Brasil", "directed by": "", "duration": 112, "rating": 3.28, "vote_count": 3315, "type": "lm", "genre": ["História", "Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["direção de arte"], "title": "Veneza", "directed by": "", "duration": 90, "rating": 3.20, "vote_count": 567, "type": "lm", "genre": ["Romance", "Drama", "Comédia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["especial do júri"], "title": "30 Anos Blues", "directed by": "", "duration": 80, "rating": 2.57, "vote_count": 58, "type": "lm", "genre": ["Drama"]},

    # Curta-metragens vencedores do Festival de Gramado de 2019
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["filme"], "title": "Apneia", "directed by": "", "duration": 15, "rating": 4.21, "vote_count": 172, "type": "cm", "genre": ["Animação", "Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2018, "award_category": ["diretor"], "title": "Menino Pássaro", "directed by": "", "duration": 15, "rating": 3.44, "vote_count": 62, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["ator", "especial do júri"], "title": "Marie", "directed by": "", "duration": 24, "rating": 3.94, "vote_count": 161, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["ator"], "title": "A Mulher que Sou", "directed by": "", "duration": 15, "rating": 3.58, "vote_count": 128, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["roteiro"], "title": "O Véu de Amani", "directed by": "", "duration": 15, "rating": 3.28, "vote_count": 60, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["fotografia"], "title": "A Ética das Hienas", "directed by": "", "duration": 20, "rating": 3.40, "vote_count": 45, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["montagem"], "title": "Invasão Espacial", "directed by": "", "duration": 14, "rating": 4.60, "vote_count": 21, "type": "cm", "genre": ["Ficção científica", "Suspense"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2018, "award_category": ["música"], "title": "Teoria Sobre um Planeta Estranho", "directed by": "", "duration": 13, "rating": 3.42, "vote_count": 90, "type": "cm", "genre": ["Drama", "Romance", "Comédia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2019, "release_year": 2019, "award_category": ["direção de arte"], "title": "Sangro", "directed by": "", "duration": 8, "rating": 3.60, "vote_count": 285, "type": "cm", "genre": ["Documentário", "Animação"]},    


    # Longa-metragens vencedores do Festival de Gramado de 2020
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["filme", "ator", "música", "júri popular"], "title": "King Kong en Asunción", "directed by": "", "duration": 90, "rating": 3.36, "vote_count": 262, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["diretor", "fotografia"], "title": "Aos Pedaços", "directed by": "", "duration": 93, "rating": 3.08, "vote_count": 273, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["ator", "roteiro", "direção de arte", "júri da crítica"], "title": "Um Animal Amarelo", "directed by": "", "duration": 115, "rating": 3.29, "vote_count": 550, "type": "lm", "genre": ["Drama", "Fantasia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["montgem"], "title": "Me Chama Que Eu Vou", "directed by": "", "duration": 70, "rating": 3.40, "vote_count": 190, "type": "lm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["música"], "title": "Todos os Mortos", "directed by": "", "duration": 120, "rating": 3.13, "vote_count": 1301, "type": "lm", "genre": ["Drama", "História"]},

    # Curta-metragens vencedores do Festival de Gramado de 2020
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["filme", "diretor", "fotografia", "direção de arte", "júri popular"], "title": "O Barco e O Rio", "directed by": "", "duration": 17, "rating": 3.52, "vote_count": 164, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["ator", "montagem"], "title": "Você tem Olhos Tristes", "directed by": "", "duration": 18, "rating": 2.91, "vote_count": 113, "type": "cm", "genre": ["Ficção"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["ator", "roteiro", "júri da crítica"], "title": "Inabitável", "directed by": "", "duration": 20, "rating": 3.62, "vote_count": 797, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["música"], "title": "Atordoado, Eu Permaneço Atento", "directed by": "", "duration": 15, "rating": 3.66, "vote_count": 150, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2020, "release_year": 2020, "award_category": ["especial do júri"], "title": "Receita de Caranguejo", "directed by": "", "duration": 19, "rating": 3.00, "vote_count": 156, "type": "cm", "genre": ["Drama", "Ficção"]},
    

    # Longa-metragens vencedores do Festival de Gramado de 2021
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2021, "award_category": ["filme", "música", "direção de arte", "especial do júri"], "title": "Carro Rei", "directed by": "", "duration": 99, "rating": 2.92, "vote_count": 1547, "type": "lm", "genre": ["Comédia", "Drama", "Ficção científica"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2021, "award_category": ["direção", "roteiro"], "title": "Jesus Kid", "directed by": "", "duration": 88, "rating": 2.90, "vote_count": 542, "type": "lm", "genre": ["Faroeste", "Comédia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2021, "award_category": ["ator", "júri popular"], "title": "O Novelo", "directed by": "", "duration": 95, "rating": 3.60, "vote_count": 611, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2021, "award_category": ["ator"], "title": "A Suspeita", "directed by": "", "duration": 92, "rating": 2.93, "vote_count": 343, "type": "lm", "genre": ["Drama", "Crime", "Suspense"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2021, "award_category": ["fotografia", "júri da crítica"], "title": "A Primeira Morte de Joana", "directed by": "", "duration": 91, "rating": 3.42, "vote_count": 949, "type": "lm", "genre": ["Drama"]},

    # Curta-metragens vencedores do Festival de Gramado de 2021
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2020, "award_category": ["filme", "direção de arte"], "title": "A Fome de Lázaro", "directed by": "", "duration": 17, "rating": 3.94, "vote_count": 98, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2019, "award_category": ["direção", "montagem", "júri da crítica", "especial do júri"], "title": "Entre nós e o Mundo", "directed by": "", "duration": 17, "rating": 3.75, "vote_count": 154, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2020, "award_category": ["ator", "roteiro"], "title": "Fotos Privadas", "directed by": "Marcelo Grabowsky", "duration": 20, "rating": 3.36, "vote_count": 298, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2020, "award_category": ["ator"], "title": "Quanto Pesa", "directed by": "Breno Nina", "duration": 23, "rating": 3.19, "vote_count": 71, "type": "cm", "genre": ["Ficção"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2021, "award_category": ["fotografia", "música"], "title": "Animais na Pista", "directed by": "Otto Cabral", "duration": 9, "rating": 3.33, "vote_count": 215, "type": "cm", "genre": ["Ficção"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2021, "release_year": 2021, "award_category": ["júri popular"], "title": "Desvirtude", "directed by": "Gautier Lee", "duration": 15, "rating": 3.11, "vote_count": 720, "type": "cm", "genre": ["Drama"]},
    

    # Longa-metragens vencedores do Festival de Gramado de 2022
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2022, "award_category": ["filme", "ator", "júri da crítica"], "title": "Noites Alienígenas", "directed by": "", "duration": 91, "rating": 3.39, "vote_count": 4534, "type": "lm", "genre": ["Crime", "Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2022, "award_category": ["roteiro", "música", "júri popular", "especial do júri"], "title": "Marte Um", "directed by": "", "duration": 115, "rating": 3.89, "vote_count": 30412, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2022, "award_category": ["fotografia", "montagem", "direção de arte"], "title": "Tinnitus", "directed by": "", "duration": 105, "rating": 3.05, "vote_count": 914, "type": "lm", "genre": ["Drama", "Romance", "Horror"]},

    # Curta-metragens vencedores do Festival de Gramado de 2022
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2021, "award_category": ["filme", "ator", "júri da crítica"], "title": "Fantasma Neon", "directed by": "Leonardo Martinelli", "duration": 20, "rating": 3.48, "vote_count": 1155, "type": "cm", "genre": ["Drama", "Música"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2022, "award_category": ["ator", "fotografia", "direção de arte"], "title": "Último Domingo", "directed by": "Renan Brandão", "duration": 17, "rating": 3.61, "vote_count": 135, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2021, "award_category": ["roteiro"], "title": "O Pato", "directed by": "Antônio Galdino", "duration": 11, "rating": 4.36, "vote_count": 75, "type": "cm", "genre": ["Ficção"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2022, "award_category": ["montagem", "júri popular"], "title": "O Elemento Tinta", "directed by": ["Iuri Salles", "Luiz Maudonnet"], "duration": 9, "rating": 4.08, "vote_count": 13, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2021, "award_category": ["especial do júri"], "title": "Serrão", "directed by": "Marcelo Lin", "duration": 18, "rating": 2.88, "vote_count": 62, "type": "cm", "genre": ["Drama", "Suspense", "Policial"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2022, "release_year": 2022, "award_category": ["música"], "title": "Um Tempo Para Mim", "directed by": "Paola Mallmann", "duration": 21, "rating": 3.05, "vote_count": 37, "type": "cm", "genre": ["Drama"]},
    

    # Longa-metragens vencedores do Festival de Gramado de 2023
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2023, "award_category": ["filme", "ator", "música", "júri popular"], "title": "Mussum, o Filmis", "directed by": "", "duration": 122, "rating": 3.51, "vote_count": 8147, "type": "lm", "genre": ["História", "Drama", "Comédia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2023, "award_category": ["diretor", "fotografia", "montagem", "especial do júri"], "title": "Mais Pesado é o Céu", "directed by": "", "duration": 98, "rating": 3.43, "vote_count": 1332, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2023, "award_category": ["ator", "roteiro", "direção de arte", "júri da crítica"], "title": "Tia Virgínia", "directed by": "", "duration": 97, "rating": 3.72, "vote_count": 3017, "type": "lm", "genre": ["Drama"]},

    # Curta-metragens vencedores do Festival de Gramado de 2023
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2023, "award_category": ["direção de arte"], "title": "Casa de Bonecas", "directed by": "George Pedrosa", "duration": 16, "rating": 3.41, "vote_count": 224, "type": "cm", "genre": ["Horror", "Fantasia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2022, "award_category": ["montage", "júri da crítica"], "title": "Camaco", "directed by": "Breno Alvarenga", "duration": 14, "rating": 3.70, "vote_count": 41, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2022, "award_category": ["roteiro", "ator", "júri popular"], "title": "Ela Mora Logo Ali", "directed by": ["Fabiano Tertuliano de Barros", "Rafael Rogante"], "duration": 16, "rating": 3.71, "vote_count": 220, "type": "cm", "genre": ["Drama", "Família"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2023, "award_category": ["ator"], "title": "Sabão Líquido", "directed by": ["Fernanda Reis", "Gabriel Faccini"], "duration": 21, "rating": 3.51, "vote_count": 81, "type": "cm", "genre": ["Ficção"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2023, "award_category": ["fotografia", "especial do júri"], "title": "Mãri Hi: A Árvore do Sonho", "directed by": "Morzaniel Ɨramari Yanomami", "duration": 17, "rating": 3.54, "vote_count": 242, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2023, "award_category": ["diretor"], "title": "Deixa", "directed by": "Mariana Jaspe", "duration": 15, "rating": 3.43, "vote_count": 214, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2023, "release_year": 2023, "award_category": ["filme"], "title": "Remendo", "directed by": ["Roger Ghil", "GG FÁKỌ̀LÀDÉ"], "duration": 20, "rating": 3.61, "vote_count": 317, "type": "cm", "genre": ["Drama"]},
    

    # Longa-metragens vencedores do Festival de Gramado de 2024
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["filme", "fotografia"], "title": "Oeste Outra Vez", "directed by": "", "duration": 97, "rating": 3.80, "vote_count": 13065, "type": "lm", "genre": ["Drama", "Faroeste"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["diretor"], "title": "Filhos do Mangue", "directed by": "", "duration": 110, "rating": 2.68, "vote_count": 140, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["ator", "roteiro", "direção de arte", "música", "júri popular"], "title": "Estômago II: O Poderoso Chef", "directed by": "", "duration": 131, "rating": 2.78, "vote_count": 5458, "type": "lm", "genre": ["Comédia", "Drama", "Crime"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["ator", "júri da crítica"], "title": "Cidade; Campo", "directed by": "", "duration": 120, "rating": 3.29, "vote_count": 2913, "type": "lm", "genre": ["Horror", "Drama", "Mistério"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["montgem"], "title": "Barba Ensopada de Sangue", "directed by": "", "duration": 108, "rating": 3.28, "vote_count": 256, "type": "lm", "genre": ["Suspense"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["especial do júri"], "title": "O Clube das Mulheres de Negócios", "directed by": "", "duration": 95, "rating": 2.80, "vote_count": 1685, "type": "lm", "genre": ["Drama", "Comédia"]},

    # Curta-metragens vencedores do Festival de Gramado de 2024
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["filme", "fotografia", "montagem"], "title": "Pastrana", "directed by": ["Gabriel Motta", "Melissa Brogni"], "duration": 15, "rating": 3.57, "vote_count": 225, "type": "cm", "genre": ["Documentário"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["diretor", "direção de arte"], "title": "Maputo", "directed by": "Lucas Abrahao", "duration": 15, "rating": 3.63, "vote_count": 175, "type": "cm", "genre": ["Drama", "Fantasia"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["roteiro"], "title": "A Casa Amarela", "directed by": "Adriel Nizer", "duration": 14, "rating": 3.58, "vote_count": 59, "type": "cm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["ator", "música", "especial do júri"], "title": "Ponto e Vírgula", "directed by": "Thiago Kistenmacker", "duration": 17, "rating": 3.74, "vote_count": 119, "type": "cm", "genre": ["Drama", "Romance"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["ator", "júri da crítica"], "title": "Fenda", "directed by": "Lis Paim", "duration": 23, "rating": 3.99, "vote_count": 143, "type": "cm", "genre": ["Drama", "Família"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2024, "release_year": 2024, "award_category": ["júri popular"], "title": "Ana Cecília", "directed by": "Julia Regis", "duration": 20, "rating": 3.91, "vote_count": 77, "type": "cm", "genre": ["Ficção"]},


    # Premiados do Festival de Gramado 2025
    {"festival_name": "Festival de Gramado", "festival_year": 2025, "release_year": 2025, "award_category": ["filme", "roteiro", "montagem"], "title": "Cinco Tipos de Medo", "directed by": "", "duration": 109, "rating": 3.77, "vote_count": 117, "type": "lm", "genre": ["Drama", "Suspense", "Crime", "Ação"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2025, "release_year": 2025, "award_category": ["diretor", "fotografia", "júri da crítica"], "title": "Nó", "directed by": "", "duration": 91, "rating": 3.92, "vote_count": 169, "type": "lm", "genre": ["Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2025, "release_year": 2025, "award_category": ["ator", "direção de arte", "júri popular"], "title": "Papagaios", "directed by": "", "duration": 90, "rating": 3.78, "vote_count": 182, "type": "lm", "genre": ["Suspense", "Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2025, "release_year": 2025, "award_category": ["ator"], "title": "Querido Mundo", "directed by": "", "duration": 95, "rating": 3.21, "vote_count": 69, "type": "lm", "genre": ["Comédia", "Romance", "Drama"]},
    {"festival_name": "Festival de Gramado", "festival_year": 2025, "release_year": 2025, "award_category": ["música", "especial do júri"], "title": "A Natureza das Coisas Invisíveis", "directed by": "", "duration": 90, "rating": 3.82, "vote_count": 1670, "type": "lm", "genre": ["Drama"]},

]

# %%
# Dicionário de Correções de Diretores (2019 a 2025)
# Fontes: Festival de Gramado, AdoroCinema, G1, Papo de Cinema.
updates_directors_all = {
    # 2019 Longas
    "Pacarrete": "Allan Deberton",
    "O Homem Cordial": "Iberê Carvalho",
    "Raia 4": "Emiliano Cunha",
    "Hebe: A Estrela do Brasil": "Maurício Farias",
    "Veneza": "Miguel Falabella",
    "30 Anos Blues": "Andradina Azevedo e Dida Andrade",
    # 2019 Curtas
    "Apneia": "Carol Sakura e Walkir Fernandes",
    "Menino Pássaro": "Diogo Leite",
    "Marie": "Leo Tabosa",
    "A Mulher que Sou": "Nathália Tereza",
    "O Véu de Amani": "Renata Diniz",
    "A Ética das Hienas": "Rodolpho de Barros",
    "Invasão Espacial": "Thiago Foresti",
    "Teoria Sobre um Planeta Estranho": "Marco Antônio Pereira",
    "Sangro": "Tiago Minamisawa, Bruno H Castro e Guto BR",

    # 2020 Longas
    "King Kong en Asunción": "Camilo Cavalcante",
    "Aos Pedaços": "Ruy Guerra",
    "Um Animal Amarelo": "Felipe Bragança",
    "Me Chama Que Eu Vou": "Joana Mariani",
    "Todos os Mortos": "Caetano Gotardo e Marco Dutra",
    # 2020 Curtas
    "O Barco e O Rio": "Bernardo Ale Abinader",
    "Você tem Olhos Tristes": "Diogo Leite",
    "Inabitável": "Matheus Farias e Enock Carvalho",
    "Atordoado, Eu Permaneço Atento": "Henrique Amud e Lucas H. Rossi",
    "Receita de Caranguejo": "Issis Valenzuela",

    # 2021 Longas
    "Carro Rei": "Renata Pinheiro",
    "Jesus Kid": "Aly Muritiba",
    "O Novelo": "Cláudia Pinheiro",
    "A Suspeita": "Pedro Peregrino",
    "A Primeira Morte de Joana": "Cristiane Oliveira",
    # 2021 Curtas
    "A Fome de Lázaro": "Diego Benevides",
    "Entre nós e o Mundo": "Fábio Rodrigo",
    "Quanto Pesa": "Breno Nina",
    "Animais na Pista": "Otto Cabral",
    "Desvirtude": "Gautier Lee",

    # 2022 Longas (Caso presentes na sua lista cortada)
    "Noites Alienígenas": "Sérgio de Carvalho",
    "Marte Um": "Gabriel Martins",
    "A Mãe": "Cristiano Burlan",
    "Tinnitus": "Gregório Graziosi",
    # 2022 Curtas
    "Fantasma Neon": "Leonardo Martinelli",
    "O Pato": "Antônio Galdino",
    "O Elemento Tinta": "Luiz Maudonnet e Iuri Salles",
    "Um Tempo para Mim": "Paola Mallmann",

    # 2023 Longas
    "Mussum, O Filmis": "Silvio Guindane",
    "Mais Pesado é o Céu": "Petrus Cariry",
    "Tia Virgínia": "Fábio Meira",
    "Hamlet": "Zeca Brito",
    # 2023 Curtas
    "Remendo": "Roger Ghil",
    "Ela Mora Logo Ali": "Fabiano Barros e Rafael Rogante",
    "Deixa": "Mariana Jaspe",
    "Camaco": "Breno Alvarenga",
    
    # 2024 e 2025
    "Pastrana": "Melissa Brogni e Gabriel Motta",
    "Maputo": "Lucas Abrahão",
    "A Casa Amarela": "Adriel Nizer",
    "Ponto e Vírgula": "Thiago Kistenmacker",
    "Fenda": "Lis Paim",
    "Ana Cecília": "Julia Regis",
    "Papagaios": "Douglas Soares",
    "Querido Mundo": "Miguel Falabella e Hsu Chien",
    "A Natureza das Coisas Invisíveis": "Rafaela Camelo",
    "Oeste Outra Vez": "Érico Rassi",
    "Estômago 2": "Marcos Jorge",
    "Cidade; Campo": "Juliana Rojas",
    "Cinco Tipos de Medo": "Bruno Bini",
    "Nó": "Laís Melo"
}

# Código para aplicar as atualizações na lista highlights
count_updated = 0
for movie in highlights:
    title = movie.get("title")
    # Verifica se o título está no dicionário de atualizações
    # E aplica apenas se o campo 'directed by' estiver vazio ou nulo
    current_director = movie.get("directed by")
    if title in updates_directors_all:
        if not current_director or current_director == "":
            movie["directed by"] = updates_directors_all[title]
            count_updated += 1
            # print(f"Atualizado: {title} -> {movie['directed by']}") # Descomente para ver o log

print(f"Total de filmes atualizados com diretores: {count_updated}")
# Out:
# Total de filmes atualizados com diretores: 44

# %%
import json
import os

# Define o caminho relativo: sobe um nível (..) e entra em (data)
output_dir = '../data'
file_path = os.path.join(output_dir, 'movies_master.json')

# Garante que a pasta 'data' existe para não dar erro
os.makedirs(output_dir, exist_ok=True)

# Salva a lista 'highlights'
with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(highlights, f, ensure_ascii=False, indent=4)

print(f"Arquivo mestre salvo em: {os.path.abspath(file_path)}")
# Out:
# Arquivo mestre salvo em: c:\Users\usuario\Desktop\Data Science\project_cinema_br_npl\data\movies_master.json

# %%
import pandas as pd

# %%
columns = [
    "festival_year", 
    "release_year",
    "title", 
    "directed by", 
    "duration", 
    "rating", 
    "vote_count", 
    "type", 
    "genre"
]

dados_brutos = [
    (2015, 2015, "Introdução à Música do Sangue", "Luiz Carlos Lacerda", 95, 1.90, 50, "lm", "Drama"),
    (2015, 2015, "O Fim e os Meios", "Murilo Salles", 105, 2.51, 72, "lm", ["Drama", "Política"]),
    (2016, 2016, "Aquarius", "Kleber Mendonça Filho", 147, 3.97, 57331, "lm", "Drama"),
    (2016, 2016, "O Silêncio do Céu", "Marco Dutra", 102, 3.35, 2681, "lm", "Thriller"),
    (2016, 2016, "Tamo Junto", "Matheus Souza", 100, 3.04, 422, "lm", "Comédia"),
    (2017, 2017, "João, o Maestro", "Mauro Lima", 117, 3.24, 414, "lm", ["Biografia", "Drama", "Música"]),
    (2017, 2017, "A Fera na Selva", ["Paulo Betti", "Eliane Giardini"], 90, 3.30, 100, "lm", "Drama"),
    (2017, 2017, "Médico de Monstro", "Gustavo Teixeira", 11, 3.77, 26, "cm", "Ficção"),
    (2017, 2016, "Caminho dos Gigantes", "Alois Di Leo", 12, 3.68, 322, "cm", ["Fantasia", "Música", "Animação"]),
    (2018, 2018, "Mormaço", "Marina Meliande", 94, 3.27, 585, "lm", ["Drama", "Fantasia", "Horror"]),
    (2018, 2018, "A Cidade dos Piratas", "Otto Guerra", 80, 3.63, 736, "lm", "Animação"),
    (2019, 2018, "A Pedra", "Iuli Gerbase", 20, 3.24, 63, "cm", "Drama"),
    (2019, 2019, "E o que a gente faz agora?", "Marina Pontes", 15, 3.02, 22, "cm", "Drama"),
    (2019, 2019, "O Balido Interno", "Eder Deó", 15, 3.69, 27, "cm", "Drama"),
    (2019, 2019, "Vou Nadar Até Você", "Klaus Mitteldorf", 107, 2.88, 368, "lm", "Drama"),
    (2019, 2019, "Bacurau", ["Juliano Dornelles", "Kleber Mendonça Filho"], 132, 3.91, 163395, "lm", ["Ação", "Aventura", "Mistério"]),
    (2019, 2019, "Legalidade", "Zeca Brito", 122, 3.14, 314, "lm", ["Drama", "História", "Política"]),
    (2020, 2020, "Por Que Você Não Chora?", "Cibele Amaral", 98, 3.01, 686, "lm", "Drama"),
    (2022, 2022, "A Porta ao Lado", "Julia Rezende", 114, 2.99, 802, "lm", "Drama"),
    (2022, 2020, "O Clube dos Anjos", "Angelo Defanti", 101, 3.44, 914, "lm", "Drama"),
    (2022, 2022, "O Pastor e o Guerrilheiro", "José Eduardo Belmonte", 115, 3.34, 533, "lm", "Drama"),
    (2022, 2021, "Benzedeira", ["San Marcelo", "Pedro Olaia"], 15, 3.54, 40, "cm", "Documentário"),
    (2022, 2022, "Deus Não Deixa", "Marçal Vianna", 20, 4.02, 173, "cm", "Documentário"),
    (2022, 2021, "Mas Eu Não Sou Alguém", ["Gabriel Duarte", "Daniel Eduardo"], 13, 3.69, 18, "cm", "Ficção"),
    (2022, 2022, "O Fim da Imagem", "Gil Baroni", 15, 2.89, 37, "cm", ["Ficção", "Drama"]),
    (2022, 2021, "Solitude", ["Tami Martins", "Aron Miranda"], 13, 3.98, 133, "cm", "Animação"),
    (2022, 2022, "Tekoha", "Carlos Adriano", 14, 3.26, 53, "cm", "Documentário"),
    (2023, 2023, "Angela", "Hugo Prata", 104, 2.50, 4288, "lm", ["Biografia", "Drama"]),
    (2023, 2023, "O Barulho da Noite", "Eva Pereira", 96, 3.79, 75, "lm", "Drama"),
    (2023, 2023, "Uma Família Feliz", "José Eduardo Belmonte", 117, 3.15, 20672, "lm", ["Suspense", "Thriller"]),
    (2023, 2023, "Anhangabaú", "Lufe Bollini", 75, 3.28, 34, "lm", "Documentário"),
    (2023, 2023, "Da Porta Pra Fora", "Thiago Foresti", 84, 3.15, 13, "lm", "Documentário"),
    (2023, 2023, "Luis Fernando Verissimo: O Filme", "Luzimar Stricher", 120, 2.86, 14, "lm", "Documentário"),
    (2023, 2023, "Memórias da Chuva", "Wolney Oliveira", 79, 3.88, 33, "lm", "Documentário"),
    (2023, 2023, "Roberto Farias: Memórias de Um Cineasta", "Marise Farias", 92, 3.73, 66, "lm", "Documentário"),
    (2023, 2023, "Yãmî Yah-Pá: Fim da Noite", "Vladimir Seixas", 17, 3.43, 68, "cm", ["Documentário", "Terror"]),
    (2023, 2023, "Cama Vazia", ["Fábio Rogério", "Jean-Claude Bernardet"], 6, 3.26, 159, "cm", "Documentário"),
    (2023, 2023, "Jussara", "Camila Ribeiro", 9, 3.51, 81, "cm", "Animação"),
    (2024, 2024, "Poemaria", "Davi Kinski", 75, 3.71, 21, "lm", "Documentário"),
    (2024, 2024, "Toquinho Maravilhoso", "Alejandro Berger Parrado", 95, 3.19, 8, "lm", ["Documentário", "Biografia", "Musical"]),
    (2024, 2024, "Mestras", ["Aíla", "Roberta Carvalho"], 63, 4.00, 20, "lm", "Documentário"),
    (2024, 2024, "Castanho", ["Adanilo", "Victor Kaleb"], 20, 3.38, 82, "cm", "Drama"),
    (2024, 2022, "Movimentos Migratórios", "Rogério Cathalá", 22, 3.90, 77, "cm", "Ficção")
]

# %%
no_winners = []
cols = ["festival_year", "release_year", "title", "directed by", "duration", "rating", "vote_count", "type", "genre"]

for i in dados_brutos:
    filme = dict(zip(cols, i))
    
    filme["festival_name"] = "Festival de Gramado"
    filme["award_category"] = []
    
    if isinstance(filme["genre"], str):
        filme["genre"] = [filme["genre"]]
        
    no_winners.append(filme)

lista_final_completa = highlights + no_winners


output_dir = '../data'
file_path = os.path.join(output_dir, 'movies_master_completo.json')

os.makedirs(output_dir, exist_ok=True)

with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(lista_final_completa, f, ensure_ascii=False, indent=4)

print(f"Arquivo salvo com sucesso contendo {len(lista_final_completa)} filmes (vencedores + indicados).")
# Out:
# Arquivo salvo com sucesso contendo 160 filmes (vencedores + indicados).
